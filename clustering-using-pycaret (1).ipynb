# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/credit-card-customer-data/Credit Card Customer Data.csv

# %%
import time

# %%
customer = pd.read_csv('/kaggle/input/credit-card-customer-data/Credit Card Customer Data.csv')

# %%
customer.head()
# Out:
#    Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 0      1         87073            100000                   2
# 1      2         38414             50000                   3
# 2      3         17341             50000                   7
# 3      4         40496             30000                   5
# 4      5         47437            100000                   6
#
#    Total_visits_bank  Total_visits_online  Total_calls_made
# 0                  1                    1                 0
# 1                  0                   10                 9
# 2                  1                    3                 4
# 3                  1                    1                 4
# 4                  0                   12                 3

# %%
customer.corr()
# Out:
#                         Sl_No  Customer Key  Avg_Credit_Limit  \
# Sl_No                1.000000      0.052886          0.677962
# Customer Key         0.052886      1.000000          0.068604
# Avg_Credit_Limit     0.677962      0.068604          1.000000
# Total_Credit_Cards   0.739329     -0.010281          0.608860
# Total_visits_bank    0.406438     -0.000560         -0.100312
# Total_visits_online  0.033916      0.022506          0.551385
# Total_calls_made    -0.684125      0.005968         -0.414352
#
#                      Total_Credit_Cards  Total_visits_bank  \
# Sl_No                          0.739329           0.406438
# Customer Key                  -0.010281          -0.000560
# Avg_Credit_Limit               0.608860          -0.100312
# Total_Credit_Cards             1.000000           0.315796
# Total_visits_bank              0.315796           1.000000
# Total_visits_online            0.167758          -0.551861
# ...

# %%
customer.drop(['Sl_No','Customer Key'],axis=1 ,inplace = True)

# %%
customer.head()
# Out:
#    Avg_Credit_Limit  Total_Credit_Cards  Total_visits_bank  \
# 0            100000                   2                  1
# 1             50000                   3                  0
# 2             50000                   7                  1
# 3             30000                   5                  1
# 4            100000                   6                  0
#
#    Total_visits_online  Total_calls_made
# 0                    1                 0
# 1                   10                 9
# 2                    3                 4
# 3                    1                 4
# 4                   12                 3

# %%
pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.5/160.5 kB 4.0 MB/s eta 0:00:00
# done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.9/485.9 kB 16.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 18.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 16.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 63.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 59.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 75.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.9/21.9 MB 16.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 88.6 MB/s eta 0:00:00
# ...

# %%
from pycaret.utils import version
version()
# Out:
# '3.3.0'

# %%
from pycaret.clustering import*

# %% [markdown]
# **Kmeans Algorithm**

# %%
# NO DATA PROCESSING
kMeanClusteringParameters=setup(customer)
for i in range(3,6):
    print('FOR K = '+ str(i))
    KMeanClusteringModel = create_model('kmeans', num_clusters=i)
#     kMeanPrediction = assign_model(KMeanClusteringModel)
#     print(kMeanPrediction)
#     evaluate_model(KMeanClusteringModel)
#     plot_model(KMeanClusteringModel, plot='cluster')
#     plot_model(KMeanClusteringModel, plot = 'tsne')
#     plot_model(KMeanClusteringModel, plot = 'elbow')
#     plot_model(KMeanClusteringModel, plot = 'distribution')
#     plot_model(KMeanClusteringModel, plot = 'distance')
#     plot_model(KMeanClusteringModel, plot = 'silhouette')
# Out:
# <style type="text/css">
# #T_2fcd2_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2fcd2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2fcd2_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_2fcd2_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2fcd2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2fcd2_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_2fcd2_row0_col1" class="data row0 col1" >4378</td>
#     </tr>
#     <tr>
#       <th id="T_2fcd2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2fcd2_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_2fcd2_row1_col1" class="data row1 col1" >(660, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_2fcd2_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# NORMALIZED DATA PROCESSING
kMeanClusteringParameters=setup(data = customer, normalize = True, normalize_method = 'zscore', verbose=False)
for i in range(3,6):
    print('FOR K = '+ str(i))
    KMeanClusteringModel = create_model('kmeans', num_clusters=i)
#     kMeanPrediction = assign_model(KMeanClusteringModel)
#     print(kMeanPrediction)
#     evaluate_model(KMeanClusteringModel)
#     plot_model(KMeanClusteringModel, plot='cluster')
#     plot_model(KMeanClusteringModel, plot = 'tsne')
#     plot_model(KMeanClusteringModel, plot = 'elbow')
#     plot_model(KMeanClusteringModel, plot = 'distribution')
#     plot_model(KMeanClusteringModel, plot = 'distance')
#     plot_model(KMeanClusteringModel, plot = 'silhouette')
# Out:
# FOR K = 3
# <style type="text/css">
# </style>
# <table id="T_b0f7e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b0f7e_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_b0f7e_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_b0f7e_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_b0f7e_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_b0f7e_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_b0f7e_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b0f7e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b0f7e_row0_col0" class="data row0 col0" >0.5157</td>
#       <td id="T_b0f7e_row0_col1" class="data row0 col1" >833.3426</td>
# ...

# %%
# Transformed DATA PROCESSING
kMeanClusteringParameters=setup(data = customer, transformation = True, transformation_method = 'yeo-johnson', verbose=False)
for i in range(3,6):
    print('FOR K = '+ str(i))
    KMeanClusteringModel = create_model('kmeans', num_clusters=i)
#     kMeanPrediction = assign_model(KMeanClusteringModel)
#     print(kMeanPrediction)
#     evaluate_model(KMeanClusteringModel)
#     plot_model(KMeanClusteringModel, plot='cluster')
#     plot_model(KMeanClusteringModel, plot = 'tsne')
#     plot_model(KMeanClusteringModel, plot = 'elbow')
#     plot_model(KMeanClusteringModel, plot = 'distribution')
#     plot_model(KMeanClusteringModel, plot = 'distance')
#     plot_model(KMeanClusteringModel, plot = 'silhouette')
# Out:
# FOR K = 3
# <style type="text/css">
# </style>
# <table id="T_e9849">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e9849_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_e9849_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_e9849_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_e9849_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_e9849_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_e9849_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e9849_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e9849_row0_col0" class="data row0 col0" >0.4903</td>
#       <td id="T_e9849_row0_col1" class="data row0 col1" >673.7086</td>
# ...

# %%
# PCA DATA PROCESSING
kMeanClusteringParameters=setup(data = customer,pca = True, pca_method = 'linear', verbose=False)
for i in range(3,6):
    print('FOR K = '+ str(i))
    KMeanClusteringModel = create_model('kmeans', num_clusters=i)
#     kMeanPrediction = assign_model(KMeanClusteringModel)
#     print(kMeanPrediction)
#     evaluate_model(KMeanClusteringModel)
#     plot_model(KMeanClusteringModel, plot='cluster')
#     plot_model(KMeanClusteringModel, plot = 'tsne')
#     plot_model(KMeanClusteringModel, plot = 'elbow')
#     plot_model(KMeanClusteringModel, plot = 'distribution')
#     plot_model(KMeanClusteringModel, plot = 'distance')
#     plot_model(KMeanClusteringModel, plot = 'silhouette')
# Out:
# FOR K = 3
# <style type="text/css">
# </style>
# <table id="T_2de3c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2de3c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_2de3c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_2de3c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_2de3c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_2de3c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_2de3c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2de3c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2de3c_row0_col0" class="data row0 col0" >0.7187</td>
#       <td id="T_2de3c_row0_col1" class="data row0 col1" >2937.6564</td>
# ...

# %%
 # NORMALIZE AND TRANSFORMED DATA PROCESSING
kMeanClusteringParameters=setup(data = customer,transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)
for i in range(3,6):
    print('FOR K = '+ str(i))
    KMeanClusteringModel = create_model('kmeans', num_clusters=i)
#     kMeanPrediction = assign_model(KMeanClusteringModel)
#     print(kMeanPrediction)
#     evaluate_model(KMeanClusteringModel)
#     plot_model(KMeanClusteringModel, plot='cluster')
#     plot_model(KMeanClusteringModel, plot = 'tsne')
#     plot_model(KMeanClusteringModel, plot = 'elbow')
#     plot_model(KMeanClusteringModel, plot = 'distribution')
#     plot_model(KMeanClusteringModel, plot = 'distance')
#     plot_model(KMeanClusteringModel, plot = 'silhouette')
# Out:
# FOR K = 3
# <style type="text/css">
# </style>
# <table id="T_4983e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4983e_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_4983e_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_4983e_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_4983e_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_4983e_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_4983e_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4983e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4983e_row0_col0" class="data row0 col0" >0.4625</td>
#       <td id="T_4983e_row0_col1" class="data row0 col1" >521.3481</td>
# ...

# %%
 # NORMALIZE AND TRANSFORMED AND PCA DATA PROCESSING
kMeanClusteringParameters=setup(data = customer,transformation = True, normalize = True,pca=True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson',pca_method = 'linear', verbose=False)
for i in range(3,6):
    print('FOR K = '+ str(i))
    KMeanClusteringModel = create_model('kmeans', num_clusters=i)
#     kMeanPrediction = assign_model(KMeanClusteringModel)
#     print(kMeanPrediction)
#     evaluate_model(KMeanClusteringModel)
#     plot_model(KMeanClusteringModel, plot='cluster')
#     plot_model(KMeanClusteringModel, plot = 'tsne')
#     plot_model(KMeanClusteringModel, plot = 'elbow')
#     plot_model(KMeanClusteringModel, plot = 'distribution')
#     plot_model(KMeanClusteringModel, plot = 'distance')
#     plot_model(KMeanClusteringModel, plot = 'silhouette')
# Out:
# FOR K = 3
# <style type="text/css">
# </style>
# <table id="T_4e787">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4e787_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_4e787_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_4e787_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_4e787_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_4e787_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_4e787_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4e787_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4e787_row0_col0" class="data row0 col0" >0.4625</td>
#       <td id="T_4e787_row0_col1" class="data row0 col1" >521.3481</td>
# ...

# %% [markdown]
# **Agglomerative Algorithm**

# %%
# no data preprocessing
AgglomerativeClusteringParameters=setup(data = customer)
for i in range(3,6):
    print('FOR K = '+ str(i))
    AgglomerativeClusteringModel = create_model('hclust', num_clusters=i)
# Out:
# <style type="text/css">
# #T_d0b6e_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d0b6e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d0b6e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d0b6e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d0b6e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d0b6e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d0b6e_row0_col1" class="data row0 col1" >5632</td>
#     </tr>
#     <tr>
#       <th id="T_d0b6e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d0b6e_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_d0b6e_row1_col1" class="data row1 col1" >(660, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_d0b6e_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# normalize preprocessing
AgglomerativeClusteringParameters=setup(data = customer,normalize=True,normalize_method = 'zscore', verbose=False)
for i in range(3,6):
    print('FOR K = '+ str(i))
    AgglomerativeClusteringModel = create_model('hclust', num_clusters=i)
# Out:
# FOR K = 3
# <style type="text/css">
# </style>
# <table id="T_ab011">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ab011_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_ab011_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_ab011_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_ab011_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_ab011_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_ab011_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ab011_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ab011_row0_col0" class="data row0 col0" >0.5148</td>
#       <td id="T_ab011_row0_col1" class="data row0 col1" >831.9308</td>
# ...

# %%
# transform preprocessing
AgglomerativeClusteringParameters=setup(data = customer,transformation=True,transformation_method = 'yeo-johnson',verbose=False)
for i in range(3,6):
    print('FOR K = '+ str(i))
    AgglomerativeClusteringModel = create_model('hclust', num_clusters=i)
# Out:
# FOR K = 3
# <style type="text/css">
# </style>
# <table id="T_d5670">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d5670_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_d5670_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_d5670_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_d5670_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_d5670_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_d5670_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d5670_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d5670_row0_col0" class="data row0 col0" >0.4896</td>
#       <td id="T_d5670_row0_col1" class="data row0 col1" >670.3064</td>
# ...

# %%
# normalize and transform preprocessing
AgglomerativeClusteringParameters=setup(data = customer,normalize=True,normalize_method = 'zscore',transformation=True,transformation_method = 'yeo-johnson',verbose=False)
for i in range(3,6):
    print('FOR K = '+ str(i))
    AgglomerativeClusteringModel = create_model('hclust', num_clusters=i)
# Out:
# FOR K = 3
# <style type="text/css">
# </style>
# <table id="T_b1950">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b1950_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_b1950_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_b1950_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_b1950_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_b1950_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_b1950_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b1950_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b1950_row0_col0" class="data row0 col0" >0.4616</td>
#       <td id="T_b1950_row0_col1" class="data row0 col1" >517.2629</td>
# ...

# %%
#pca preprocessing
AgglomerativeClusteringParameters=setup(data = customer,pca=True, pca_method='linear' ,verbose=False)
for i in range(3,6):
    print('FOR K = '+ str(i))
    AgglomerativeClusteringModel = create_model('hclust', num_clusters=i)
# Out:
# FOR K = 3
# <style type="text/css">
# </style>
# <table id="T_18121">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_18121_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_18121_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_18121_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_18121_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_18121_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_18121_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_18121_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_18121_row0_col0" class="data row0 col0" >0.6811</td>
#       <td id="T_18121_row0_col1" class="data row0 col1" >1914.3066</td>
# ...

# %%
# normalize and transform and pca preprocessing
AgglomerativeClusteringParameters=setup(data = customer,pca=True, pca_method='linear' ,normalize=True,normalize_method = 'zscore',transformation=True,transformation_method = 'yeo-johnson',verbose=False)
for i in range(3,6):
    print('FOR K = '+ str(i))
    AgglomerativeClusteringModel = create_model('hclust', num_clusters=i)
# Out:
# FOR K = 3
# <style type="text/css">
# </style>
# <table id="T_fb7a7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fb7a7_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_fb7a7_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_fb7a7_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_fb7a7_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_fb7a7_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_fb7a7_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fb7a7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fb7a7_row0_col0" class="data row0 col0" >0.4616</td>
#       <td id="T_fb7a7_row0_col1" class="data row0 col1" >517.2629</td>
# ...

# %% [markdown]
# **DBSCAN Algorithm**

# %%
# no data preprocessing
# dbscan may not work for data that is not normalized
dbscanClusteringParameters=setup(data = customer)
for i in range(3,6):
    print('FOR K = '+ str(i))
    dbscanClusteringModel = create_model('dbscan', eps=1, min_samples=10)
# Out:
# <style type="text/css">
# #T_e4a85_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e4a85">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e4a85_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e4a85_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e4a85_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e4a85_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e4a85_row0_col1" class="data row0 col1" >7737</td>
#     </tr>
#     <tr>
#       <th id="T_e4a85_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e4a85_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_e4a85_row1_col1" class="data row1 col1" >(660, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_e4a85_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# normalize preprocessing
dbscanClusteringParameters=setup(data = customer,normalize=True,normalize_method = 'zscore',verbose=False)
for i in range(3,6):
    print('FOR K = '+ str(i))
    dbscanClusteringModel = create_model('dbscan', eps=0.8, min_samples=10 )
# Out:
# FOR K = 3
# <style type="text/css">
# </style>
# <table id="T_1178e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1178e_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_1178e_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_1178e_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_1178e_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_1178e_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_1178e_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1178e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1178e_row0_col0" class="data row0 col0" >0.5511</td>
#       <td id="T_1178e_row0_col1" class="data row0 col1" >332.4236</td>
# ...

# %%
# no preprocessing
kmodesClusteringParameters=setup(data = customer)
for i in range(3,6):
    print('FOR K = '+ str(i))
    kmodesClusteringModel = create_model('kmodes', num_clusters=i)
# Out:
# <style type="text/css">
# #T_df07a_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_df07a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_df07a_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_df07a_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_df07a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_df07a_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_df07a_row0_col1" class="data row0 col1" >2913</td>
#     </tr>
#     <tr>
#       <th id="T_df07a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_df07a_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_df07a_row1_col1" class="data row1 col1" >(660, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_df07a_level0_row2" class="row_heading level0 row2" >2</th>
# ...
